# %% [markdown]
# # Task Overview
#
# Use this notebook as a lightweight control panel for one major task. Keep reproducible processing in scripts and use this notebook for checks, plots, and interpretation.

# %%
from pathlib import Path
import json
import pandas as pd

state_path = Path('../../docs/state.json')
with open(state_path, 'r', encoding='utf-8') as f:
    state = json.load(f)
print(json.dumps(state, indent=2))
# Out:
# {
#   "project": "republic-ner-matching",
#   "last_updated": "2026-08-31",
#   "active_focus": "Segmentation transfer: implement S0 boundary evaluation harness before S4 assembly; S3 manual boundary annotation remains pending.",
#   "tasks": [
#     {
#       "id": "S0",
#       "title": "Boundary evaluation harness",
#       "status": "todo",
#       "notes": "Add boundary P/R/F1 at tolerance t, WindowDiff or P_k, and exact-count satisfaction. Blocking for S5."
#     },
#     {
#       "id": "S1",
#       "title": "Zero-annotation diagnostics",
#       "status": "done",
#       "notes": "D1, D1c, D2, and D2b completed; findings support segmentation-transfer framing."
#     },
#     {
#       "id": "S2",
#       "title": "Anchor phrase inventory",
#       "status": "done",
#       "notes": "Harvested 1626-1630 opening/closing phrases to output/s2_anchor_phrase_inventory.json."
#     },
#     {
#       "id": "S3-tooling",
#       "title": "Boundary gold tooling",
# ...

# %% [markdown]
# ## Notes
#
# Record observations here, then promote durable decisions to `docs/DECISIONS.md`.
